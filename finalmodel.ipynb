# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('result1.csv',parse_dates=True,index_col='Date')
df
# Out:
#             Close_HDB     Close_GC   Close_BZ  Close_INR  Negative  Neutral  \
# Date
# 02-01-2003   1.359000   346.100006  75.739998  45.709999       NaN      NaN
# 03-01-2003   1.359000   351.200012  77.050003  45.629002       NaN      NaN
# 06-01-2003   1.380000   351.700012  75.349998  45.549999       NaN      NaN
# 07-01-2003   1.368000   347.299988  75.760002  45.548000       NaN      NaN
# 08-01-2003   1.350000   353.899994  74.750000  45.449001       NaN      NaN
# ...               ...          ...        ...        ...       ...      ...
# 22-04-2020  40.779999  1640.000000        NaN        NaN       NaN      NaN
# 23-04-2020  40.880001  1640.000000        NaN        NaN       NaN      NaN
# 24-04-2020  39.950001  1564.099976        NaN        NaN       NaN      NaN
# 27-04-2020  40.590000  1592.300049        NaN        NaN       NaN      NaN
# 28-04-2020  40.840000  1642.099976        NaN        NaN       0.0      0.0
#
#             Positive
# Date
# ...

# %%
df=df.iloc[:3287]
df
# Out:
#             Close_HDB     Close_GC   Close_BZ  Close_INR  Negative  Neutral  \
# Date
# 02-01-2003   1.359000   346.100006  75.739998  45.709999       NaN      NaN
# 03-01-2003   1.359000   351.200012  77.050003  45.629002       NaN      NaN
# 06-01-2003   1.380000   351.700012  75.349998  45.549999       NaN      NaN
# 07-01-2003   1.368000   347.299988  75.760002  45.548000       NaN      NaN
# 08-01-2003   1.350000   353.899994  74.750000  45.449001       NaN      NaN
# ...               ...          ...        ...        ...       ...      ...
# 28-09-2015  29.084999  1089.400024  20.370001  67.174004       NaN      NaN
# 29-09-2015  30.059999  1090.699951  21.330000  67.359001       NaN      NaN
# 30-09-2015  30.545000  1085.699951  21.440001  66.830002       NaN      NaN
# 01-10-2015  30.965000  1090.199951  19.990000  66.612000       0.0      1.0
# 02-10-2015  31.299999  1094.099976  20.459999  66.375999       0.0      1.0
#
#             Positive
# Date
# ...

# %%
df['Neutral']=df['Neutral'].fillna(1.0)
df['Negative']=df['Negative'].fillna(0.0)
df['Positive']=df['Positive'].fillna(0.0)

df
# Out:
# <ipython-input-92-dbd08e9325f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Neutral']=df['Neutral'].fillna(1.0)
# <ipython-input-92-dbd08e9325f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Negative']=df['Negative'].fillna(0.0)
# <ipython-input-92-dbd08e9325f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.isna().sum()
# Out:
# Close_HDB     0
# Close_GC     48
# Close_BZ     59
# Close_INR    29
# Negative      0
# Neutral       0
# Positive      0
# dtype: int64

# %%
df=df.dropna()
df.isna().sum()
# Out:
# Close_HDB    0
# Close_GC     0
# Close_BZ     0
# Close_INR    0
# Negative     0
# Neutral      0
# Positive     0
# dtype: int64

# %%
df
# Out:
#             Close_HDB     Close_GC   Close_BZ  Close_INR  Negative  Neutral  \
# Date
# 02-01-2003   1.359000   346.100006  75.739998  45.709999       0.0      1.0
# 03-01-2003   1.359000   351.200012  77.050003  45.629002       0.0      1.0
# 06-01-2003   1.380000   351.700012  75.349998  45.549999       0.0      1.0
# 07-01-2003   1.368000   347.299988  75.760002  45.548000       0.0      1.0
# 08-01-2003   1.350000   353.899994  74.750000  45.449001       0.0      1.0
# ...               ...          ...        ...        ...       ...      ...
# 28-09-2015  29.084999  1089.400024  20.370001  67.174004       0.0      1.0
# 29-09-2015  30.059999  1090.699951  21.330000  67.359001       0.0      1.0
# 30-09-2015  30.545000  1085.699951  21.440001  66.830002       0.0      1.0
# 01-10-2015  30.965000  1090.199951  19.990000  66.612000       0.0      1.0
# 02-10-2015  31.299999  1094.099976  20.459999  66.375999       0.0      1.0
#
#             Positive
# Date
# ...

# %%
df['Close_HDB'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1=pd.read_csv('result1.csv')
df1=df1.iloc[:3287]
df1['Neutral']=df1['Neutral'].fillna(1.0)
df1['Negative']=df1['Negative'].fillna(0.0)
df1['Positive']=df1['Positive'].fillna(0.0)
df1=df1.dropna()
df1
# Out:
#             Date  Close_HDB     Close_GC   Close_BZ  Close_INR  Negative  \
# 0     02-01-2003   1.359000   346.100006  75.739998  45.709999       0.0
# 1     03-01-2003   1.359000   351.200012  77.050003  45.629002       0.0
# 2     06-01-2003   1.380000   351.700012  75.349998  45.549999       0.0
# 3     07-01-2003   1.368000   347.299988  75.760002  45.548000       0.0
# 4     08-01-2003   1.350000   353.899994  74.750000  45.449001       0.0
# ...          ...        ...          ...        ...        ...       ...
# 3282  28-09-2015  29.084999  1089.400024  20.370001  67.174004       0.0
# 3283  29-09-2015  30.059999  1090.699951  21.330000  67.359001       0.0
# 3284  30-09-2015  30.545000  1085.699951  21.440001  66.830002       0.0
# 3285  01-10-2015  30.965000  1090.199951  19.990000  66.612000       0.0
# 3286  02-10-2015  31.299999  1094.099976  20.459999  66.375999       0.0
#
#       Neutral  Positive
# 0         1.0       0.0
# 1         1.0       0.0
# ...

# %%
close_df=df1.drop('Date',axis=1)
close_df=close_df.dropna()

# %%
close_df.columns
# Out:
# Index(['Close_HDB', 'Close_GC', 'Close_BZ', 'Close_INR', 'Negative', 'Neutral',
#        'Positive'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

y=close_df[['Close_HDB']]
x=close_df[['Close_GC', 'Close_BZ', 'Close_INR','Negative', 'Neutral',
       'Positive']]
print(x.shape,y.shape)
# Out:
# (3154, 6) (3154, 1)

# %%
x_train=x.iloc[:3060]
x_test=x.iloc[3060:3125]
y_train=y.iloc[:3060]
y_test=y.iloc[3060:3125]
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (3060, 6) (65, 6)
# (3060, 1) (65, 1)

# %%
rr=RandomForestRegressor(n_estimators=100, random_state=42)
rr.fit(x_train,y_train)

y_pred = rr.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# <ipython-input-121-6be4f65749aa>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rr.fit(x_train,y_train)
# Mean Squared Error: 1.1732747414694717

# %%
y_pred.shape
# Out:
# (65,)

# %%
y_test.shape
# Out:
# (65, 1)

# %%
y_pred=np.array(y_pred)
y_pred=y_pred.flatten()
y_pred
# Out:
# array([30.90244976, 30.93019974, 30.48909979, 30.72599986, 30.4098497 ,
#        30.49014971, 30.7322497 , 29.73749988, 29.87979987, 29.46120019,
#        29.46120019, 29.96909994, 30.35135001, 29.43350023, 29.86514995,
#        29.95114994, 30.38895   , 30.20569995, 30.20569995, 29.9240501 ,
#        30.19884997, 30.26769998, 30.4030998 , 30.39264993, 29.99410011,
#        30.32174996, 29.59480015, 29.96350004, 29.92624988, 29.80554964,
#        29.5647998 , 29.63779993, 30.2108498 , 30.14579971, 30.28414969,
#        30.24604946, 30.24039939, 30.06964961, 30.12929962, 30.43094943,
#        30.25344945, 30.50354939, 30.52214946, 30.52354945, 30.60069949,
#        30.21109982, 30.11699981, 30.6242995 , 30.47029949, 29.69954982,
#        30.42484952, 30.50999948, 30.53359944, 30.51709946, 30.50999948,
#        30.53359944, 30.51709946, 30.50999948, 30.54049945, 30.54049945,
#        30.53359944, 30.50999948, 30.39554954, 30.39554954, 30.39554954])

# %%
y_test=np.array(y_test)
y_test=y_test.flatten()
y_test
# Out:
# array([29.385   , 29.690001, 29.610001, 29.809999, 29.799999, 29.280001,
#        28.594999, 28.495001, 28.645   , 28.235001, 28.235001, 28.094999,
#        28.57    , 28.334999, 28.325001, 28.18    , 28.325001, 28.514999,
#        28.514999, 28.855   , 28.975   , 29.74    , 29.934999, 29.93    ,
#        30.785   , 30.625   , 30.165001, 30.264999, 30.91    , 30.825001,
#        30.889999, 31.225   , 29.799999, 30.08    , 30.91    , 30.98    ,
#        30.93    , 30.99    , 31.825001, 31.934999, 31.870001, 30.895   ,
#        31.200001, 31.025   , 30.754999, 30.535   , 30.735001, 30.785   ,
#        30.875   , 31.235001, 31.485001, 31.469999, 31.530001, 31.299999,
#        31.495001, 31.514999, 31.15    , 31.52    , 31.42    , 31.475   ,
#        31.445   , 30.995001, 30.705   , 30.094999, 29.969999])

# %%
from tabulate import tabulate

table_data = zip(y_test, y_pred)
headers = ["Actual", "Predicted"]

# Format the table
table = tabulate(table_data, headers=headers, floatfmt=".6f")

# Print the formatted table
print(table)
# Out:
#    Actual    Predicted
# ---------  -----------
# 29.385000    30.902450
# 29.690001    30.930200
# 29.610001    30.489100
# 29.809999    30.726000
# 29.799999    30.409850
# 29.280001    30.490150
# 28.594999    30.732250
# 28.495001    29.737500
# 28.645000    29.879800
# 28.235001    29.461200
# 28.235001    29.461200
# 28.094999    29.969100
# 28.570000    30.351350
# 28.334999    29.433500
# 28.325001    29.865150
# 28.180000    29.951150
# 28.325001    30.388950
# 28.514999    30.205700
# 28.514999    30.205700
# 28.855000    29.924050
# 28.975000    30.198850
# 29.740000    30.267700
# 29.934999    30.403100
# 29.930000    30.392650
# 30.785000    29.994100
# 30.625000    30.321750
# 30.165001    29.594800
# 30.264999    29.963500
# 30.910000    29.926250
# 30.825001    29.805550
# 30.889999    29.564800
# 31.225000    29.637800
# 29.799999    30.210850
# 30.080000    30.145800
# 30.910000    30.284150
# 30.980000    30.246049
# 30.930000    30.240399
# 30.990000    30.069650
# ...

# %%
#prediction
to_pred=x.iloc[3126:]
actual=y.iloc[3126:]
pred_val=rr.predict(to_pred)
pred_val

print(pred_val.shape)
# Out:
# (28,)

# %%
mse1 = mean_squared_error(pred_val, actual)
print("Mean Squared Error:", mse1)
# Out:
# Mean Squared Error: 1.1060970417200708

# %%
fig, ax = plt.subplots()

# Plot y_pred
ax.plot(y_pred, label='Predicted')

# Plot y_test
ax.plot(y_test, label='Actual')

# Add labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Value')
ax.set_title('Comparison of Predicted and Actual Values')

# Add legend
ax.legend()
ax.set_ylim(0, 80)
# Show the plot
plt.show()

# %%
def assess_risks(predicted_prices, historical_prices, financial_metrics):


    # Calculate the expected return based on the predicted prices
    expected_return = (predicted_prices[-1] - predicted_prices[0]) / predicted_prices[0]

    # Calculate historical volatility
    historical_returns = [(historical_prices[i] - historical_prices[i-1]) / historical_prices[i-1] for i in range(1, len(historical_prices))]
    historical_volatility = np.std(historical_returns)

    # Assess risks based on financial metrics and volatility
    if expected_return > 0.05:  # Example threshold for expected return
        if financial_metrics['P/E ratio'] < 15:  # Example threshold for P/E ratio
            decision = 'Invest'
        else:
            decision = 'Hold'
    elif expected_return < -0.05 or historical_volatility > 0.2:  # Example thresholds for expected return and volatility
        decision = 'Avoid'
    else:
        decision = 'Hold'

    return decision

# Example usage:
preds=pred_val[17:28]
actuals=actual.iloc[17:28]
predicted_prices =np.array(preds)
historical_prices =np.array(actuals)
financial_metrics = {'P/E ratio': 19.41, 'Debt/Equity ratio': 0.91}
decision = assess_risks(predicted_prices, historical_prices, financial_metrics)
print("Investment Decision:", decision)
# Out:
# Investment Decision: Hold
